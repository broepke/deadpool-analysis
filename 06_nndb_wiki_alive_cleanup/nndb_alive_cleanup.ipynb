# %% [markdown]
# # Further Analysis and Clean Up of Wiki Death Cause Data

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

# %%
from collections import Counter
import numpy as np
import pandas as pd
import re
import spacy
from spacy.lang.en import English

# %%
# Load Spacy English language model
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Perform Categorization

# %%
def remove_phrases(text, phrases_to_remove):
    # Create a temporary variable with the lowercase text
    temp_text = text.lower()
    
    # Perform the replacement on the lowercase text
    for phrase in phrases_to_remove:
        temp_text = temp_text.replace(phrase.lower(), '')

    # Now, reconstruct the original text with phrases removed
    result_text = ""
    start = 0
    for i in range(len(text)):
        if text[i].lower() != temp_text[start:start+1]:
            continue
        else:
            result_text += text[i]
            start += 1
    
    return result_text

# %%
# Function to process text with Spacy, remove stop words and unwanted phrases
def spacy_process(text, phrases_to_remove):
    if not isinstance(text, str):
        return []
    text = remove_phrases(text, phrases_to_remove)
    doc = nlp(text)
    return [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]

# %%
def categorize_cause_spacy(cause, key_terms, term_mappings):
    if not isinstance(cause, str):  # Check if cause is a string
        return None  # Return "unknown" for non-string inputs (like NaN)

    # First check specific terms in the mappings
    for term, category in term_mappings.items():
        if term in cause:
            return category

    # Then check general terms
    for term in key_terms:
        if term in cause:
            return term

    return "other"

# %%
# Function to check and replace strings containing any no_info_terms
def remove_no_info_terms(text):
    
    
    # Standardize No Information Entries and Normalize Text
    no_info_terms = ["health care",
                     "healthcare",
                     "health coverage",
                     "no relevant section found",
                     "unknown",
                     "there is no",
                     "it is not possible to determine",
                     "any specific health issue",
                     "significant health issue",
                     "care act",
                     "obamacare",
                     "aca",
                     "medicare", 
                     "medicaid",
                     "insurance",
                     "sorry provided text contain information"
                     ]
    
    # Combine all terms into a single regex pattern
    # Join the terms with '|', which acts as an 'OR' operator in regex
    regex_pattern = '|'.join(map(re.escape, no_info_terms))
    
    if isinstance(text, str) and re.search(regex_pattern, text, re.IGNORECASE):
        return np.nan
    return text

# %%
def clean_and_categorize_data_spacy(file_path):
    # Load the CSV file
    data = pd.read_csv(file_path)

     
    # data['Health_Issues'] = data['Health_Issues'].str.lower().apply(
    #     lambda x: np.nan if isinstance(x, str) and any(term in x for term in no_info_terms) else x)
    
    # Apply the function to the 'Health_Issues' column
    data['Health_Issues'] = data['Health_Issues'].str.lower().apply(remove_no_info_terms)

    # List of phrases to remove
    phrases_to_remove = ["cause of death: ", "death cause: ", "complications from ", 
                            "the cause of death was ",
                            "indications significant health issue mentioned ",
                            "possible determine specific health issue ",
                            "The most significant health issue mentioned in the text is ",
                            "The most significant health issue found in the text is ",
                            "The most significant health issue in the text is ",
                            "There are multiple health issues mentioned in the text, but the most significant one is "
                            ]

    # Process text and remove unwanted phrases
    data['Health_Issues'] = data['Health_Issues'].str.lower().apply(lambda x: ' '.join(spacy_process(x, phrases_to_remove)) if isinstance(x, str) else x)

    # Key terms and their mappings
    key_terms = ['cancer', 'heart', 'stroke', 'accident', 'suicide', 'murder',
                 'organ failure', 'pneumonia', 'respiratory', 'natural causes',
                 'tumor', 'diabetes', 'brain', 'poisoning', 
                 'liver', 'illness', 'als', 'kidney', 'assassination', 'tuberculosis', 
                 'overdose', 'alzheimer', 'parkinson', 'drowning', 'covid-19', 'aids', 
                 'bronchitis', 'surgery', 'fever', 'infection', 'blood', 'hemorrhage', 'asphyxiation',
                 'concussions', 'pacemaker', 'tinnitus', 'obesity', 'alcoholism' 'anorexia',
                 'opioid', 'lead contamination', 'hepatitis', 'seizures', 'aneurysm', 'pre existing conditions',
                 'reproductive', 'drug addiction', 'tobacco']
    
    term_mappings = {'injury': 'accident', 'cardiac arrest': 'heart', 'blunt trauma': 'accident', 'leukemia': 'cancer',
                     'cardiac':'heart', 'myeloma': 'cancer', 'cerebral': 'brain', 'gunshot': 'murder', 'hanged':'suicide',
                     'lymphoma': 'cancer', 'shot':'murder', 'mesothelioma':'cancer', 'stab': 'murder',
                     'cirrhosis':'liver', 'crash':'accident', 'collision':'accident', 'dementia':'alzheimer',
                     'fall':'accident', 'hanging':'suicide', 'cardiovascular':'heart', 'knife wound':'murder',
                     'unspecified': 'unknown', 'emphysema':'respiratory', 'aortic':'heart', 'thrombosis':'blood',
                     'coronary':'heart', 'lung':'respiratory', 'pulmonary': 'respiratory', 'coronavirus':'covid-19',
                     'abortion':'reproductive', 'diabetic': 'diabetes', 'eating disorders': 'anorexia',
                     'leukaemia': 'cancer', 'smoking': 'tobacco', 'pre existing medical conditions': 'pre existing conditions'}

    # Categorize the causes of death
    data['Categorized_Cause'] = data['Health_Issues'].apply(lambda x: categorize_cause_spacy(x, key_terms, term_mappings))

    return data

# %%
file_path = '../04_nndb_wiki_alive_lookup/wiki_alive_output.csv'
cleaned_data_spacy = clean_and_categorize_data_spacy(file_path)

# %% [markdown]
# ### Write the File to Disk for the Seed

# %%
# Get rid of this one bad value i can't fix
index_to_drop = cleaned_data_spacy[cleaned_data_spacy['ID'] == 'b2332e48a1298b58fd1bf6ab1ca5d12b'].index
# Dropping the row by its index
cleaned_data_spacy = cleaned_data_spacy.drop(index_to_drop)

# Get rid of all rows with null values for better SQL join
df_seed = cleaned_data_spacy.dropna(subset=['Health_Issues'])

# Presist this analysis to a CSV
df_seed.to_csv('seed_nndb_alive_causes.csv', index=False)

# %%
cleaned_data_spacy.dropna(inplace=True)
filtered_unknown = cleaned_data_spacy[cleaned_data_spacy['Health_Issues'] != 'unknown']
filtered_data = filtered_unknown[filtered_unknown['Categorized_Cause'] == 'other']
print(filtered_data[['Health_Issues', 'Categorized_Cause']].sample(25))
# Out:
#                            Health_Issues Categorized_Cause
# 15446                              fraud             other
# 7405                     spinal stenosis             other
# 17743                      pre eclampsia             other
# 16785                access medical care             other
# 19525                               lyme             other
# 2487                      herniated disc             other
# 5401                 acid reflux disease             other
# 17402                       overcrowding             other
# 3441   obsessive compulsive disorder ocd             other
# 7318                               fraud             other
# 18894                            bulimia             other
# 314                    asperger syndrome             other
# 11880                          uninsured             other
# 16656                             sepsis             other
# 5999                                 hiv             other
# 12581           traumatic encephalopathy             other
# 9143                     breast implants             other
# 11131                 multiple sclerosis             other
# 11419                         alcoholism             other
# 19926                   anorexia nervosa             other
# 9286                              health             other
# 18133                         depression             other
# 17481               mental health issues             other
# 15390                       lyme disease             other
# 14980                      hydrocephalus             other

# %%
cleaned_data_spacy['Categorized_Cause'].value_counts()
# Out:
# Categorized_Cause
# other                      173
# cancer                      84
# heart                       20
# covid-19                    19
# stroke                      16
# reproductive                13
# diabetes                    12
# alzheimer                    7
# respiratory                  7
# obesity                      7
# hepatitis                    6
# pre existing conditions      5
# kidney                       4
# accident                     4
# tobacco                      4
# tumor                        4
# pneumonia                    4
# blood                        4
# aids                         3
# parkinson                    3
# opioid                       3
# aneurysm                     2
# liver                        2
# tinnitus                     2
# seizures                     2
# drug addiction               2
# brain                        2
# pacemaker                    2
# illness                      2
# concussions                  1
# infection                    1
# als                          1
# lead contamination           1
# anorexia                     1
# suicide                      1
# surgery                      1
# Name: count, dtype: int64

# %%
cleaned_data_spacy['Health_Issues'].value_counts()
# Out:
# Health_Issues
# cancer                     26
# breast cancer              22
# covid-19                   17
# prostate cancer            15
# stroke                     14
#                            ..
# heart bypass surgery        1
# lung issues                 1
# kidney failure              1
# spinal stenosis             1
# guillain barré syndrome     1
# Name: count, Length: 231, dtype: int64

# %% [markdown]
# ## Examine Remaing Word Frequencies

# %%
def print_common_words(common_words):
    for word, freq in common_words:
        print(f"Word: '{word}', Frequency: {freq}")

# %%
def most_common_words(dataframe, column_name):
    text = ' '.join(dataframe[column_name].dropna())  # Join all text and handle NaN values
    doc = nlp(text)
    
    # Filter tokens that are stop words or punctuations
    words = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct and not token.is_space]

    # Count the words
    word_freq = Counter(words)

    return word_freq.most_common(30)  # You can adjust the number to get more or less frequent words

# Usage
common_words = most_common_words(filtered_data, 'Health_Issues')
print_common_words(common_words)
# Out:
# Word: 'health', Frequency: 24
# Word: 'disorder', Frequency: 10
# Word: 'care', Frequency: 8
# Word: 'disease', Frequency: 7
# Word: 'mental', Frequency: 7
# Word: 'sclerosis', Frequency: 6
# Word: 'bipolar', Frequency: 5
# Word: 'multiple', Frequency: 5
# Word: 'syndrome', Frequency: 4
# Word: 'injuries', Frequency: 4
# Word: 'preexisting', Frequency: 4
# Word: 'conditions', Frequency: 4
# Word: 'uninsured', Frequency: 4
# Word: 'medical', Frequency: 4
# Word: 'depression', Frequency: 4
# Word: 'ménière', Frequency: 3
# Word: 'diseases', Frequency: 3
# Word: 'alcoholism', Frequency: 3
# Word: 'flu', Frequency: 3
# Word: 'issues', Frequency: 3
# Word: 'arthritis', Frequency: 3
# Word: 'reform', Frequency: 3
# Word: 'lyme', Frequency: 3
# Word: 'chronic', Frequency: 2
# Word: 'issue', Frequency: 2
# Word: 'affordable', Frequency: 2
# Word: 'neurological', Frequency: 2
# Word: 'hip', Frequency: 2
# Word: 'nutrition', Frequency: 2
# Word: 'covid', Frequency: 2

# %% [markdown]
# ## Examine Bi-Grams

# %%
# Load Spacy English language model
nlp = English()
nlp.add_pipe('sentencizer')  # Add sentencizer to the pipeline

# %%
def most_common_bigrams(dataframe, column_name):
    text = ' '.join(dataframe[column_name].dropna())  # Join all text and handle NaN values
    doc = nlp(text)

    # Create bigrams
    bigrams = []
    for sent in doc.sents:
        tokens = [token.text.lower() for token in sent if not token.is_stop and not token.is_punct and not token.is_space]
        bigrams.extend(zip(tokens, tokens[1:]))

    # Count the bigrams
    bigram_freq = Counter(bigrams)

    return bigram_freq.most_common(30)  # Adjust number for more/less frequent bigrams

# %%
common_bigrams = most_common_bigrams(filtered_data, 'Health_Issues')
print_common_words(common_bigrams)
# Out:
# Word: '('mental', 'health')', Frequency: 7
# Word: '('health', 'care')', Frequency: 6
# Word: '('multiple', 'sclerosis')', Frequency: 5
# Word: '('bipolar', 'disorder')', Frequency: 4
# Word: '('preexisting', 'conditions')', Frequency: 4
# Word: '('ménière', 'disease')', Frequency: 3
# Word: '('health', 'issue')', Frequency: 2
# Word: '('care', 'health')', Frequency: 2
# Word: '('health', 'substance')', Frequency: 2
# Word: '('health', 'issues')', Frequency: 2
# Word: '('health', 'services')', Frequency: 2
# Word: '('lyme', 'disease')', Frequency: 2
# Word: '('care', 'reform')', Frequency: 2
# Word: '('dissociative', 'identity')', Frequency: 1
# Word: '('identity', 'disorder')', Frequency: 1
# Word: '('disorder', 'health')', Frequency: 1
# Word: '('care', 'plan')', Frequency: 1
# Word: '('plan', 'bipolar')', Frequency: 1
# Word: '('disorder', 'asperger')', Frequency: 1
# Word: '('asperger', 'syndrome')', Frequency: 1
# Word: '('syndrome', 'attention')', Frequency: 1
# Word: '('attention', 'deficit')', Frequency: 1
# Word: '('deficit', 'hyperactivity')', Frequency: 1
# Word: '('hyperactivity', 'disorder')', Frequency: 1
# Word: '('disorder', 'oncology')', Frequency: 1
# Word: '('oncology', 'injuries')', Frequency: 1
# Word: '('injuries', 'aphasia')', Frequency: 1
# Word: '('aphasia', 'surgeries')', Frequency: 1
# Word: '('surgeries', 'ménière')', Frequency: 1
# Word: '('disease', 'amyloidosis')', Frequency: 1

# %%
filtered_data.head(50)
# Out:
#                                     ID             WIKI_PAGE  \
# 198   8a1df388700fbdc045627bcf92224841       Herschel_Walker
# 230   45c512fba6f069ce56ed24597c182337           Mark_Warner
# 278   c919e3256330ae0ed64678d04f71fb14            Kanye_West
# 314   a231439b94ad79a5e36c72ddfec3c1dc             Joe_Walsh
# 316   c7d1464b97f5dce0df9b94dbe65be318             Joe_Walsh
# 506   a6625d0ad36f985b889e179369362bb1          Alice_Walton
# 516   ae1357ab60574861eaf2932a4d52dcb1        Deryck_Whibley
# 541   115df7279300985b73a3c33faa4d2e40          Bruce_Willis
# 655   7bba3fea9896052bcaa0c82e66ccd870          Brian_Wilson
# 715   7e4d40e061568a50f3730c88ce6e0336            Dana_White
# 1198  60b3170de554e9b629a2b57f2a3d6846          Michael_York
# 1245  c6c52474ae6ae621516b736ef89fa2f3                 Youth
# 1391  0a28c92d3e75a5401aefd5ed67b663e4        Chen_Shui-bian
# 1522  5cf422a1124313bc888e980dbcc21ad8     Bruce_Springsteen
# 1831  1f7d865d0e186b70a33e39cad0044b56           Steve_Perry
# 1848  556ce76eb0cccd2faef448e683e66175           Niki_Taylor
# 2106  45e128495735d8edb65bd5addaa25cd3                 Paris
# 2183  49e77256a16591f4b08e4ca031cd000a          Mike_Quigley
# 2189  efc19c1e65b985cbde9fda148c8e4f02        Manmohan_Singh
# 2314  afdb397b486d626c8dac3981ddc15ae4         Matthew_Perry
# 2384  e509a1e291887f7ea5acd0eb066b2438          Betty_Sutton
# 2487  bdc465538ec9ab55776cc912ab0711d0       Charlize_Theron
# 2598  aaa66fd80a469bb1ba91570842ee07f2            Liam_Payne
# 2672  64e23939f60e875ac695d3fb0c6cc6c6         Dick_Van_Dyke
# 2778  ede9f0c296f8b9e284f0bf1b2bb49111         Eric_Shinseki
# 2873  ef3779f7af19cae9600c600e9940670b  Elizabeth_H._Roberts
# 3060  141eceb2aa3dedd14263463533ca67b3           LeAnn_Rimes
# 3362  8dae9780c57253182e4540249f8c0e35      Dana_Rohrabacher
# 3400  78045d7b74a382aa089fe5aa90118ae0          Brad_Sherman
# 3441  8346fe3c228ca7a8a12e7f196f37b9c4        Andy_Partridge
# 3479  d64fea47adcc8768dbb01016fad95037         Göran_Persson
# 3823  339b2b3f9f42658674d7af9086a5f35a      Chris_Van_Hollen
# 3863  02b9b9fdf920ee9e6eb65ae1d12220f7           Rick_Snyder
# 3877  52a79542abf828b378dd818bfbee9280            Kevin_Rudd
# 3971  c08782148ead09c24f6e6c84be304000           Ann_Veneman
# 4046  781125ebb4c0a0087710ab0bfd9145b2          Mike_Simpson
# 4444  a10bfc3597b0c2fa815e5f0746b16bbf        Michel_Platini
# 4552  8f75b4006f77df744cb90ea5f8bb0595          Earl_Pomeroy
# 4632  bbb83f5b20f4c1e4228f563e4412ce56                  Pelé
# 4813  337cd8a717e4b3063feec47d936a0889            Fred_Upton
# 5001  cdfff410d968016b04723f340dc4efbb         Kurt_Schrader
# 5401  ffb8eab79cce86eeb3236cd8847fba8f            Mark_Spitz
# 5514  f7933915c9469088f7f5859f895826e0           KT_Tunstall
# 5999  4c9484491ed876066c000265c6c11092         Charlie_Sheen
# 6148  1a9b9d4950a06800b398d2c672933d41              Ron_Paul
# 6245  ce6dcba39edc60266bbf5af38e13f769            Pat_Toomey
# 6301  40dbe9743358d7c95e068bb38f777c7b          Rafael_Nadal
# 6482  bcbf68d5e24d3124680269f53284a83f             Mick_Mars
# 6665  febb2fe5335bcfec79b8d5e2f16f6795         Ira_Magaziner
# 6684  bae21354c12021758e1d411645158bf4       Mary-Kate_Olsen
#
#                                  Health_Issues Categorized_Cause
# 198             dissociative identity disorder             other
# 230                           health care plan             other
# 278                           bipolar disorder             other
# 314                          asperger syndrome             other
# 316   attention deficit hyperactivity disorder             other
# 506                                   oncology             other
# 516                                   injuries             other
# 541                                    aphasia             other
# 655                                  surgeries             other
# 715                            ménière disease             other
# 1198                               amyloidosis             other
# 1245                    unintentional injuries             other
# 1391                               sleep apnea             other
# 1522                      peptic ulcer disease             other
# 1831                                  melanoma             other
# 1848                         internal injuries             other
# 2106                                    health             other
# 2183                          chronic diseases             other
# 2189                              health issue             other
# 2314              alcohol induced pancreatitis             other
# 2384                                affordable             other
# 2487                            herniated disc             other
# 2598                                alcoholism             other
# 2672                     neurological disorder             other
# 2778                               timely care             other
# 2873                                    health             other
# 3060                                 psoriasis             other
# 3362                    preexisting conditions             other
# 3400                                    health             other
# 3441         obsessive compulsive disorder ocd             other
# 3479                        hip osteoarthritis             other
# 3823                              women health             other
# 3863                   digital health coaching             other
# 3877                                disability             other
# 3971                                 nutrition             other
# 4046                                     covid             other
# 4444                                       flu             other
# 4552                            present system             other
# 4632                                    tumour             other
# 4813                                     covid             other
# 5001                               drug prices             other
# 5401                       acid reflux disease             other
# 5514                              hearing loss             other
# 5999                                       hiv             other
# 6148                                 influenza             other
# 6245                           cystic fibrosis             other
# 6301                             knee injuries             other
# 6482                    ankylosing spondylitis             other
# 6665                                    access             other
# 6684                                  anorexia             other

# %%
cleaned_data_spacy.head(50)
# Out:
#                                     ID          WIKI_PAGE  \
# 35    ea15d5d35cfbb426abd8b1461417e650   Asif_Ali_Zardari
# 134   c2c41864c52ff9f6310e537083725b63        Murray_Waas
# 176   2ba6574ad7774a0370532b809bf477f3       Rick_Wakeman
# 180   5dfdc5f3317adf707c90d0e89268cf59        Tim_Walberg
# 198   8a1df388700fbdc045627bcf92224841    Herschel_Walker
# 230   45c512fba6f069ce56ed24597c182337        Mark_Warner
# 278   c919e3256330ae0ed64678d04f71fb14         Kanye_West
# 280   5342bcdf4f1007399254cdf9d64ffaa4        Leslie_West
# 314   a231439b94ad79a5e36c72ddfec3c1dc          Joe_Walsh
# 316   c7d1464b97f5dce0df9b94dbe65be318          Joe_Walsh
# 372   cae1b6bd57e7451fb1c067a28c4c0714    T._K._Wetherell
# 422   31684c27fc62bcf461e3d20a2fb25dc4       Charlie_Weis
# 424   c9ddf9f8598d29ffcf2ca8a1143126ef    Robbie_Williams
# 451   2aacd82bc505e6305a4843624710f343    Serena_Williams
# 460   47c0a6f3b1e487892755853d79315a19    Barbara_Walters
# 506   a6625d0ad36f985b889e179369362bb1       Alice_Walton
# 516   ae1357ab60574861eaf2932a4d52dcb1     Deryck_Whibley
# 541   115df7279300985b73a3c33faa4d2e40       Bruce_Willis
# 655   7bba3fea9896052bcaa0c82e66ccd870       Brian_Wilson
# 665   b7bcdc75f74b89f878f8dcf888df6588      Charlie_Watts
# 715   7e4d40e061568a50f3730c88ce6e0336         Dana_White
# 1006  d2ad175f324993d60cd5a01c0fd91bae      Stevie_Wonder
# 1090  182640f2c0240634d0b238db66d1124f        Rob_Woodall
# 1142  e31cbd8934c8850baf55e6da8aa45e59       Lynn_Woolsey
# 1163  5f8ba8af98b2078c36a9881c3e9c9a84    Zev_Yaroslavsky
# 1198  60b3170de554e9b629a2b57f2a3d6846       Michael_York
# 1218  6a1b137ebd63001f4c401a2cca8e0a4e         Neil_Young
# 1245  c6c52474ae6ae621516b736ef89fa2f3              Youth
# 1286  91ada8895a617b273f0e1f84d4f23292      Deval_Patrick
# 1305  69f38253ee5e8e66221e4d2b19838e32     James_Rosapepe
# 1391  0a28c92d3e75a5401aefd5ed67b663e4     Chen_Shui-bian
# 1459  64f2aad219c60cc3dbdc3811cf15514f          Than_Shwe
# 1522  5cf422a1124313bc888e980dbcc21ad8  Bruce_Springsteen
# 1620  9ac5b3a32577f3e8f2741f6d883041d7          Rick_Ross
# 1621  01d9a7195c8657f8bf4ef770beaa0011     Dilma_Rousseff
# 1631  c31aff50c19efdaf65fdc9382a971220       Bobby_Rydell
# 1638  ed0fc0ebf5b475807a90e8219924f208      Steve_Stivers
# 1831  1f7d865d0e186b70a33e39cad0044b56        Steve_Perry
# 1848  556ce76eb0cccd2faef448e683e66175        Niki_Taylor
# 1925  c91b2069130a04004cbeb290d7ffcf5a      Kevin_Shields
# 1969  a1a091c199a121c17fbd1b7e4c2180ee  Jim_Sensenbrenner
# 1978  e11dffbab3ad308d5f8b2c8f515e3f34      Melania_Trump
# 1987  3d68c1615fd8716090216c13958a46c2       Maggie_Smith
# 2056  310c1b597dd8b273dd8a87e795d5acf9       Steven_Tyler
# 2106  45e128495735d8edb65bd5addaa25cd3              Paris
# 2115  bc10a17843d207e9f4fb7d3199dd5386       Randy_Travis
# 2182  50e2176010fc2954b17b44d069372605      Jack_Van_Impe
# 2183  49e77256a16591f4b08e4ca031cd000a       Mike_Quigley
# 2189  efc19c1e65b985cbde9fda148c8e4f02     Manmohan_Singh
# 2246  fed5d13410abb6c1f7bb32e6eeff6b1c          Leo_Sayer
#
#                                  Health_Issues        Categorized_Cause
# 35                                    dementia                alzheimer
# 134                              breast cancer                   cancer
# 176                                  cirrhosis                    liver
# 180                                   abortion             reproductive
# 198             dissociative identity disorder                    other
# 230                           health care plan                    other
# 278                           bipolar disorder                    other
# 280                                   diabetes                 diabetes
# 314                          asperger syndrome                    other
# 316   attention deficit hyperactivity disorder                    other
# 372                            prostate cancer                   cancer
# 422                                    obesity                  obesity
# 424                                    obesity                  obesity
# 451                         pulmonary embolism              respiratory
# 460                            aortic stenosis                    heart
# 506                                   oncology                    other
# 516                                   injuries                    other
# 541                                    aphasia                    other
# 655                                  surgeries                    other
# 665                              throat cancer                   cancer
# 715                            ménière disease                    other
# 1006                         kidney transplant                   kidney
# 1090                                  abortion             reproductive
# 1142                                  abortion             reproductive
# 1163                           type 2 diabetes                 diabetes
# 1198                               amyloidosis                    other
# 1218                            brain aneurysm                    brain
# 1245                    unintentional injuries                    other
# 1286                            drug addiction           drug addiction
# 1305                                  covid-19                 covid-19
# 1391                               sleep apnea                    other
# 1459                                  diabetic                 diabetes
# 1522                      peptic ulcer disease                    other
# 1620                                  seizures                 seizures
# 1621                                    cancer                   cancer
# 1631                                 pneumonia                pneumonia
# 1638                                  abortion             reproductive
# 1831                                  melanoma                    other
# 1848                         internal injuries                    other
# 1925                                  tinnitus                 tinnitus
# 1969           pre existing medical conditions  pre existing conditions
# 1978                          kidney condition                   kidney
# 1987                             breast cancer                   cancer
# 2056                               hepatitis c                hepatitis
# 2106                                    health                    other
# 2115                                    stroke                   stroke
# 2182                                    cancer                   cancer
# 2183                          chronic diseases                    other
# 2189                              health issue                    other
# 2246                                    cancer                   cancer
